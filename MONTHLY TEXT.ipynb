# %%
 #1.51,000

# %%
#2.30

# %%
#3.720

# %%
#4.60km/h D.70KM/h

# %%
#5.10

# %%
#6.140

# %%
#7 part B
#40

# %%
#8. cylinder

# %%
#9. u

# %%
#10. john

# %%
#11.saturday

# %%
#partc 12-15
#12): may

# %%
#13.270

# %%
#14.162

# %%
#15.apri

# %%
#partD 16-20
#16.1/2

# %%
#17.72,75and 80

# %%
#18.38

# %%
#19.18

# %%
#20.40%

# %%
#part E 21-25
#21. 4,6,8,10

# %%
#22analytics

# %%
#23.20

# %%
#24.print(nums.pop(2))print(nums)A.
30
# Out:
# 30

# %%
#25.135

# %%
#section B (1)
# logical & conceptual

#1)marks={"anu":85,"rahul":72,"akhil":91,"meera":65,"neha":78}
print("highest marks:",max(marks,key=marks.get))
# Out:
# highest marks: akhil

# %%
#2.
print("lowest marks:",min(marks,key=marks.get))
average =sum(marks.values())/len (marks)
# Out:
# lowest marks: meera

# %%
#3.print("average:",average)
new ={name:mark for name,mark in marks.items()if mark >=75}
# Out:
# average: 78.2

# %%
#4.
new ={name:mark for name,mark in marks.items()if mark >=75}
print("75 or above:",new)
# Out:
# 75 or above: {'anu': 85, 'akhil': 91, 'neha': 78}

# %%
#2.pattern printing
n=5
for i in range (1,n+1):
    for j in range (1,i+1):
        print (j,end="")
    print()
# Out:
# 1
# 12
# 123
# 1234
# 12345

# %%
#reverse pattern
for i in range (5,0,-1):
    for j in range(1,i+1):
        print(j,end="")
    print()
# Out:
# 12345
# 1234
# 123
# 12
# 1

# %%
#SECTION C
#ATM Withdrawal system (30)

balance = 10000
amount = int(input("Enter withdrawal amount:"))
if amount <= 0:
    print("Invalid amount")
elif amount > balance:
    print("Insufficient balance")
else:
    balance = balance - amount
    print("Withdrawal successful")
    print("Remaining balance:", balance)
# Out:
# Withdrawal successful
# Remaining balance: 7000
